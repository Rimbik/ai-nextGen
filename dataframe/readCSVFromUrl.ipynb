# %%
import pandas as pd
import io
import requests

url = "https://raw.githubusercontent.com/Rimbik/ai-nextGen/refs/heads/main/linear_regression/CarData.csv"
s = requests.get(url).content
c = pd.read_csv(io.StringIO(s.decode('utf-8')))

c
# Out:
#    Milege  Age(yrs)  SellPrice
# 0   69000         6      18000
# 1   35000         3      34000
# 2   57000         5      26100
# 3   22500         2      40000
# 4   44600         4      31500
# 5   59000         5      26750
# 6   52000         5      32000
# 7   72000         6      19300
# 8   91200         8      12000
# 9   67000         6      22000
