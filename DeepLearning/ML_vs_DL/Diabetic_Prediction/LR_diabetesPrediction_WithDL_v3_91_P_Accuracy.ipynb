# %%
# Predition using DeepLearning (Classification)

import tensorflow as tf
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc

# %%
# load the dataset diabates_ds
diabetes_df = pd.read_csv('diabetes_ds.csv')
diabetes_df.head()

readonly_df = diabetes_df.copy()

# %%
diabetes_df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# indentiy records with NAN, Null, NA, Inf
print(diabetes_df.isna().sum())
print("---------------------------------")
print(diabetes_df.isnull().sum())
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64
# ---------------------------------
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
# plot a bar graph with Diabets and non diabtes data (to show imbalance data)
sns.countplot(x='diabetes', data=diabetes_df)
plt.show()

# get x,y from the ds
X = diabetes_df.drop('diabetes', axis=1)
y = diabetes_df['diabetes']

from collections import Counter
print(f'Original dataset shape: {Counter(y)}')
# Out:
# Original dataset shape: Counter({0: 91500, 1: 8500})

# %%
# convert 'gender' column to binary as 1: Male 0:Female, Other = -1
diabetes_df['gender'] = diabetes_df['gender'].map({'Male': 1, 'Female': 0, 'Other' : -1})

# identify all distinct value for column 'smoking_history'
print(diabetes_df['smoking_history'].unique())

# map this '' to respective numeric value as 1: never 2:No Info 3:current etc
diabetes_df['smoking_history'] = diabetes_df['smoking_history'].map({
    'never': 0,'No Info': -1,'current': 1,'former': 2,'ever': 3,'not current': 4
})

# set X,y with SMOTE balanced date to train nmodel
X = diabetes_df.drop('diabetes', axis=1)
y = diabetes_df['diabetes']
# Out:
# ['never' 'No Info' 'current' 'former' 'ever' 'not current']

# %%
from imblearn.over_sampling import SMOTE

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Set k_neighbors to 1, the minimum possible value
smote = SMOTE(random_state=42, k_neighbors=1)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

X = X_train_resampled
y = y_train_resampled

diabetes_df = pd.DataFrame(X, columns=X.columns)
diabetes_df['diabetes'] = y

print(f'Original dataset shape: {Counter(y)}')
print(f'After SMOTE > dataset shape: {Counter(y_train_resampled)}')
# Out:
# Original dataset shape: Counter({0: 64047, 1: 64047})
# After SMOTE > dataset shape: Counter({0: 64047, 1: 64047})

# %%
# plot a bar graph with Diabets and non diabtes data (to show BALANCED data)
sns.countplot(x='diabetes', data=diabetes_df)
plt.show()

from collections import Counter
print(f'Original dataset shape: {Counter(y)}')
# Out:
# Original dataset shape: Counter({0: 64047, 1: 64047})

# %%
# set a var ctr = and set no of records founf with gender = -1\
recWithUnknownGender = len(diabetes_df[diabetes_df['gender'] == -1])
print(recWithUnknownGender)

maleCount = len(diabetes_df[diabetes_df['gender'] == 1])
print(maleCount)

femaleCount = len(diabetes_df[diabetes_df['gender'] == 0])
print(femaleCount)

#create bar chart with Male, Female, Unknown
labels = ['Male', 'Female', 'Unknown']
sizes = [maleCount, femaleCount, recWithUnknownGender]
colors = ['blue', 'pink', 'green']
explode = (0.1, 0, 0)  # explode 1st slice

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# 16
# 45452
# 82626

# %%
# convert Gender, Age to Int value from float
diabetes_df['gender'] = diabetes_df['gender'].astype(int)
diabetes_df['age'] = diabetes_df['age'].astype(int)


diabetes_df.head()
# Out:
#    gender  age  hypertension  heart_disease  smoking_history    bmi  \
# 0       1   49             0              0                3  27.32
# 1       1   64             0              0                0  27.32
# 2       0   24             0              0                1  27.32
# 3       0   55             0              0                1  27.32
# 4       1   14             0              0               -1  20.98
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          5.0                  155         0
# 1          3.5                  145         0
# 2          3.5                  130         0
# 3          6.5                  159         0
# 4          6.2                   85         0

# %%
# beofore training just make sure on the the balanced dataset
# plot the bar with Diabetes and Non Diabetes
sns.countplot(x='diabetes', data=diabetes_df)
plt.show()

X = diabetes_df.drop('diabetes', axis=1)
y = diabetes_df['diabetes']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=42)
N, D = X_train.shape
print(N, D) # train and test row count
# Out:
# 76856 8

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(len(X_train))
print(len(X_test))
print("---------")
print(len(diabetes_df))
# Out:
# 76856
# 51238
# ---------
# 128094

# %%
# Example model

# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(D,)),
    tf.keras.layers. Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
r = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50)

print("Train score:", model.evaluate(X_train, y_train))
print("Test score:", model.evaluate(X_test, y_test))
# Out:
# Epoch 1/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - accuracy: 0.8393 - loss: 0.3496 - val_accuracy: 0.8937 - val_loss: 0.2274
# Epoch 2/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8886 - loss: 0.2468 - val_accuracy: 0.9035 - val_loss: 0.2036
# Epoch 3/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8991 - loss: 0.2156 - val_accuracy: 0.9102 - val_loss: 0.1871
# Epoch 4/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9017 - loss: 0.2053 - val_accuracy: 0.9146 - val_loss: 0.1786
# Epoch 5/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9074 - loss: 0.1944 - val_accuracy: 0.9155 - val_loss: 0.1774
# Epoch 6/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9078 - loss: 0.1942 - val_accuracy: 0.9153 - val_loss: 0.1755
# Epoch 7/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9109 - loss: 0.1916 - val_accuracy: 0.9158 - val_loss: 0.1753
# Epoch 8/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9091 - loss: 0.1917 - val_accuracy: 0.9167 - val_loss: 0.1746
# Epoch 9/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9099 - loss: 0.1884 - val_accuracy: 0.9163 - val_loss: 0.1743
# Epoch 10/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9101 - loss: 0.1876 - val_accuracy: 0.9174 - val_loss: 0.1743
# Epoch 11/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9100 - loss: 0.1914 - val_accuracy: 0.9178 - val_loss: 0.1739
# Epoch 12/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9087 - loss: 0.1903 - val_accuracy: 0.9176 - val_loss: 0.1732
# Epoch 13/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9112 - loss: 0.1878 - val_accuracy: 0.9174 - val_loss: 0.1728
# Epoch 14/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9113 - loss: 0.1868 - val_accuracy: 0.9172 - val_loss: 0.1731
# Epoch 15/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9106 - loss: 0.1846 - val_accuracy: 0.9171 - val_loss: 0.1715
# Epoch 16/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9097 - loss: 0.1877 - val_accuracy: 0.9178 - val_loss: 0.1724
# Epoch 17/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9128 - loss: 0.1856 - val_accuracy: 0.9187 - val_loss: 0.1720
# Epoch 18/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9105 - loss: 0.1866 - val_accuracy: 0.9173 - val_loss: 0.1717
# Epoch 19/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9100 - loss: 0.1853 - val_accuracy: 0.9182 - val_loss: 0.1720
# Epoch 20/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9116 - loss: 0.1855 - val_accuracy: 0.9181 - val_loss: 0.1716
# Epoch 21/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9102 - loss: 0.1886 - val_accuracy: 0.9188 - val_loss: 0.1707
# Epoch 22/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9111 - loss: 0.1865 - val_accuracy: 0.9186 - val_loss: 0.1709
# Epoch 23/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9131 - loss: 0.1834 - val_accuracy: 0.9178 - val_loss: 0.1719
# Epoch 24/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9108 - loss: 0.1836 - val_accuracy: 0.9171 - val_loss: 0.1709
# Epoch 25/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9116 - loss: 0.1834 - val_accuracy: 0.9180 - val_loss: 0.1710
# Epoch 26/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9117 - loss: 0.1847 - val_accuracy: 0.9177 - val_loss: 0.1704
# Epoch 27/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9118 - loss: 0.1838 - val_accuracy: 0.9178 - val_loss: 0.1721
# Epoch 28/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9135 - loss: 0.1834 - val_accuracy: 0.9182 - val_loss: 0.1713
# Epoch 29/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9122 - loss: 0.1840 - val_accuracy: 0.9187 - val_loss: 0.1697
# Epoch 30/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9124 - loss: 0.1844 - val_accuracy: 0.9184 - val_loss: 0.1702
# Epoch 31/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9115 - loss: 0.1839 - val_accuracy: 0.9179 - val_loss: 0.1710
# Epoch 32/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9115 - loss: 0.1848 - val_accuracy: 0.9185 - val_loss: 0.1694
# Epoch 33/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9112 - loss: 0.1870 - val_accuracy: 0.9181 - val_loss: 0.1697
# Epoch 34/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9116 - loss: 0.1839 - val_accuracy: 0.9183 - val_loss: 0.1701
# Epoch 35/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9142 - loss: 0.1810 - val_accuracy: 0.9176 - val_loss: 0.1713
# Epoch 36/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9127 - loss: 0.1833 - val_accuracy: 0.9184 - val_loss: 0.1700
# Epoch 37/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9128 - loss: 0.1830 - val_accuracy: 0.9185 - val_loss: 0.1691
# Epoch 38/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9105 - loss: 0.1841 - val_accuracy: 0.9183 - val_loss: 0.1692
# Epoch 39/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9110 - loss: 0.1864 - val_accuracy: 0.9189 - val_loss: 0.1706
# Epoch 40/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9133 - loss: 0.1819 - val_accuracy: 0.9180 - val_loss: 0.1716
# Epoch 41/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9141 - loss: 0.1832 - val_accuracy: 0.9186 - val_loss: 0.1700
# Epoch 42/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9118 - loss: 0.1835 - val_accuracy: 0.9177 - val_loss: 0.1707
# Epoch 43/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9124 - loss: 0.1823 - val_accuracy: 0.9192 - val_loss: 0.1699
# Epoch 44/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9124 - loss: 0.1825 - val_accuracy: 0.9188 - val_loss: 0.1694
# Epoch 45/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9113 - loss: 0.1834 - val_accuracy: 0.9182 - val_loss: 0.1693
# Epoch 46/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9101 - loss: 0.1850 - val_accuracy: 0.9167 - val_loss: 0.1714
# Epoch 47/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9115 - loss: 0.1818 - val_accuracy: 0.9181 - val_loss: 0.1685
# Epoch 48/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9132 - loss: 0.1823 - val_accuracy: 0.9184 - val_loss: 0.1705
# Epoch 49/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9129 - loss: 0.1824 - val_accuracy: 0.9190 - val_loss: 0.1703
# Epoch 50/50
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9126 - loss: 0.1835 - val_accuracy: 0.9187 - val_loss: 0.1688
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9172 - loss: 0.1697
# Train score: [0.17188487946987152, 0.9162459373474121]
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9194 - loss: 0.1680
# Test score: [0.16878513991832733, 0.9187321662902832]

# %%
# save the model
model.save('dl_modelDiabetesPrediction.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(model.evaluate(X_train, y_train))
print(model.evaluate(X_test, y_test))
print("---------------------------------")

model.evaluate(X_test, y_test)

plt.title('Loss')
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

plt.title('Accuracy')
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()
# Out:
# 2402/2402 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9172 - loss: 0.1697
# [0.17188487946987152, 0.9162459373474121]
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9194 - loss: 0.1680
# [0.16878513991832733, 0.9187321662902832]
# ---------------------------------
# 1602/1602 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9194 - loss: 0.1680

# %%
# run inference on Test Data for prediction
# load the saved model
model = tf.keras.models.load_model('dl_modelDiabetesPrediction.h5')

testData = [
    # [0,	80,	0,	1,	-1,	25.19,	6.6,	140] # -0 : correct
    # [0,	44,	0,	0,	-1,	19.31,	6.5,	200] #  1 : wrong
    # [1,	53,	0,	0,	 1,	30.8,	  6.6,	280] #	1 : correct
    # [0,	57,	0,	0,	 1,	22.43,	6.6,	90]  #  0 : correct
      [0,	61,	0,	0,	 1,	30.11,	6.2,	240] #	1 : correct
]
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Real prediction with the model created earlier

# Scale the test data once before prediction
testData_scaled = scaler.transform(testData)

predictions = model.predict(testData_scaled)

print("\nPrediction---------")
# print Is Diabetic = Yes when value is 1, No when 0
print("Is Diabetic = 'Yes'" if predictions[0][0] > 0.5 else "Is Diabetic = 'No'")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
#
# Prediction---------
# Is Diabetic = 'Yes'

# %%
# loop the dataset 'diabetes_df' for randomn 10 records
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

ctr = 100
import random
random_numbers = random.sample(range(1000, 12000), ctr)
# loop it
total_wrongPrediction = 0
for index, value in enumerate(random_numbers):
    dsToTest = diabetes_df.iloc[value]
    isDiabetic_Actual = "'Yes'" if dsToTest['diabetes']  == 1 else "'No'"

    # drop the target col
    dsToTest = dsToTest.drop('diabetes')
    dsToTest = dsToTest.to_numpy()
    dsToTest = dsToTest.reshape(1, -1)
    # print(dsToTest) # Uncomment for debugging

    # Scale the data point before prediction
    dsToTest_scaled = scaler.transform(dsToTest)

    predictions = model.predict(dsToTest_scaled)

    print("\nPrediction---------")
    predictedVal = "'Yes'" if predictions[0][0] > 0.5 else "'No'"

    # print Is Diabetic = Yes when value is 1, No when 0
    print("Actual=", isDiabetic_Actual, ", Predicted =", predictedVal)

    if isDiabetic_Actual != predictedVal:
        total_wrongPrediction += 1

print(f"\n\nTotal wrong prediction # {total_wrongPrediction} out of {ctr}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
#
# Prediction---------
# Actual= 'Yes' , Predicted = 'Yes'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction---------
# Actual= 'No' , Predicted = 'No'
#
#
# Total wrong prediction # 9 out of 100
